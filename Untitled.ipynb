# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from dateutil import parser

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud

from lib import helpers
# Out:
# [nltk_data] Downloading package stopwords to /Users/sammd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sammd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/s_/zzcb5vrj4sq2c_nzr8v8xq900000gn/T/ipykernel_18960/3256118548.py in <module>
#      16 from wordcloud import WordCloud
#      17
# ---> 18 from lib import helpers
#
# ModuleNotFoundError: No module named 'lib'

# %%
api_key='AIzaSyApjcZ70iYJTEdwjiAJ6ytEPGkhXA9MdTE'

# %%
channel_ids=['UCPxMZIFE856tbTfdkdjzTSQ',]

# %%
api_service_name = "youtube"
api_version = "v3"
client_secrets_file = "YOUR_CLIENT_SECRET_FILE.json"

    # Get credentials and create an API client

youtube =build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data=[]

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    for item in response['items']:
        data={'channelName': item['snippet']['title'],
              'subscribers': item['statistics']['subscriberCount'],
              'view': item['statistics']['viewCount'],
              'totalVideos': item['statistics']['videoCount'],
              'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
             }
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
channel_stats=get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers        view totalVideos                playlistId
# 0  BeerBiceps     7830000  2004646921        2167  UUPxMZIFE856tbTfdkdjzTSQ

# %%
playlist_id="UUPxMZIFE856tbTfdkdjzTSQ"

def get_video_ids(youtube, playlist_id):
    video_ids=[]

    request = youtube.playlistItems().list(
        part="snippet, contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
        
    next_page_token=response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part="contentDetails",
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
        response = request.execute()
            
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        
        
        next_page_token=response.get('nextPageToken')
        
    return video_ids

# %%
playlist_id = 'UUPxMZIFE856tbTfdkdjzTSQ'

def get_video_ids(youtube, playlist_id):

    video_ids = []

    request = youtube.playlistItems().list(
        part="snippet, contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet, contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token  # Add pageToken to request the next page
        )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')

    return video_ids

# %%
video_ids=get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 2157

# %%
 request = youtube.videos().list(
     part="snippet, contentDetails, statistics",
     id=video_ids[0:5]    
    )
response = request.execute()

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
# Get video details
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#          video_id channelTitle  \
# 0     _F52bobVaEQ   BeerBiceps
# 1     OS1MckkuGak   BeerBiceps
# 2     KrHMUA3rUUY   BeerBiceps
# 3     _nY37ZdZDOE   BeerBiceps
# 4     l-ArHjfYqWE   BeerBiceps
# ...           ...          ...
# 2152  swJCVywZx0Y   BeerBiceps
# 2153  bdmWXFVuSDY   BeerBiceps
# 2154  hrQUOJllx4M   BeerBiceps
# 2155  zQZex-cKEUg   BeerBiceps
# 2156  J-gjYxabTD8   BeerBiceps
#
#                                                   title  \
# 0     Kareena Kapoor on What it Feels Like to Be BEB...
# 1              Gossip Girl BEBO Opens Up on TRS #shorts
# 2     Kareena Kapoor Reveals Her Most Difficult Role...
# 3     Why is Alexander the Great so Famous? | Abhiji...
# 4          Dulquer Salmaan On Kerala's Football Craze ⚽
# ...                                                 ...
# 2152  Are Carbs Good Or Bad? - The TRUTH And SCIENCE...
# 2153  Slow Roasted Pork Shoulder Recipe - India Spec...
# 2154  How To Lose Weight Fast For INDIANS - TOP 5 DI...
# 2155  Gym Tips For Beginners In India | BeerBiceps G...
# 2156                      The Introduction | BeerBiceps
#
#                                             description  \
# 0     Watch the full episode here:- https://youtu.be...
# 1     Watch the full episode here:- https://youtu.be...
# 2     Watch the full episode here:- https://youtu.be...
# 3     Watch the full episode here:- https://youtu.be...
# 4     Watch the Full Episode here:- https://youtu.be...
# ...                                                 ...
# 2152  Are carbs good or bad?\nIn today's video, i'm ...
# 2153  7 hour slow roasted pulled pork with beer sauc...
# 2154  How to lose weight fast - For any INDIAN - TOP...
# 2155  Gym tips for beginners - INDIA!\nHey guys, in ...
# 2156  🎧 Listen To #TheRanveerShow On Spotify:\nhttps...
#
#                                                    tags           publishedAt  \
# 0     [podcast, indian podcast, indian podcasts engl...  2024-09-21T12:30:33Z
# 1     [podcast, indian podcast, indian podcasts engl...  2024-09-21T12:02:32Z
# 2     [podcast, indian podcast, indian podcasts engl...  2024-09-21T12:00:31Z
# 3     [podcast, indian podcast, indian podcasts engl...  2024-09-20T15:30:17Z
# 4     [podcast, indian podcast, indian podcasts engl...  2024-09-20T15:30:17Z
# ...                                                 ...                   ...
# 2152  [Nutrition (Medical Specialty), Carbohydrate (...  2015-08-19T16:28:46Z
# 2153  [Pulled Pork (Food), Roasting (Culinary Techni...  2015-08-16T17:20:52Z
# 2154  [Diet (Industry), Weight Loss (Symptom), Dieti...  2015-08-15T16:57:31Z
# 2155  [India (Country), Indian gymmer, Indian gymmin...  2015-08-15T14:53:45Z
# 2156  [beerbiceps, beerbiceps first video, beerbicep...  2015-08-15T13:52:59Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0        21323       927           None            8     PT37S         hd
# 1        11567       494           None            4     PT46S         hd
# 2        57383      2998           None           20     PT39S         hd
# 3        91279      3542           None           50     PT33S         hd
# 4        65681      3017           None           25     PT43S         hd
# ...        ...       ...            ...          ...       ...        ...
# 2152     79502      2775           None          133   PT3M11S         hd
# 2153    109626      1395           None          301  PT11M14S         hd
# 2154     64504      1534           None           68    PT5M2S         hd
# 2155    116944      3473           None          147    PT5M2S         hd
# 2156    358082     12382           None          897    PT4M2S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 2152   false
# 2153   false
# 2154   false
# 2155   false
# 2156   false
#
# [2157 rows x 13 columns]

# %%
def get_comments_in_video(youtube, video_ids):

    all_comments = []
    
    for video_id in video_ids:
        try:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute() 
            comments_in_video=[comment['snippet']['topLevelComment']['snippet']['textOriginal']for comment in response['items'][0:10]]
            comments_in_video_info={'video_id':video_id, 'comments':comments_in_video}
            all_comments.append(comments_in_video_info)
        except:
            print('Could not get comments for video ' + video_id)
    return pd.DataFrame(all_comments)

# %% [markdown]
# ## Data Pre-Processing

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
#which day in the week he published video
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
 # convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#       durationSecs  duration
# 0             37.0     PT37S
# 1             46.0     PT46S
# 2             39.0     PT39S
# 3             33.0     PT33S
# 4             43.0     PT43S
# ...            ...       ...
# 2152         191.0   PT3M11S
# 2153         674.0  PT11M14S
# 2154         302.0    PT5M2S
# 2155         302.0    PT5M2S
# 2156         242.0    PT4M2S
#
# [2157 rows x 2 columns]

# %%
# add tag count
video_df['tagCount']=video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#          video_id channelTitle  \
# 0     _F52bobVaEQ   BeerBiceps
# 1     OS1MckkuGak   BeerBiceps
# 2     KrHMUA3rUUY   BeerBiceps
# 3     _nY37ZdZDOE   BeerBiceps
# 4     l-ArHjfYqWE   BeerBiceps
# ...           ...          ...
# 2152  swJCVywZx0Y   BeerBiceps
# 2153  bdmWXFVuSDY   BeerBiceps
# 2154  hrQUOJllx4M   BeerBiceps
# 2155  zQZex-cKEUg   BeerBiceps
# 2156  J-gjYxabTD8   BeerBiceps
#
#                                                   title  \
# 0     Kareena Kapoor on What it Feels Like to Be BEB...
# 1              Gossip Girl BEBO Opens Up on TRS #shorts
# 2     Kareena Kapoor Reveals Her Most Difficult Role...
# 3     Why is Alexander the Great so Famous? | Abhiji...
# 4          Dulquer Salmaan On Kerala's Football Craze ⚽
# ...                                                 ...
# 2152  Are Carbs Good Or Bad? - The TRUTH And SCIENCE...
# 2153  Slow Roasted Pork Shoulder Recipe - India Spec...
# 2154  How To Lose Weight Fast For INDIANS - TOP 5 DI...
# 2155  Gym Tips For Beginners In India | BeerBiceps G...
# 2156                      The Introduction | BeerBiceps
#
#                                             description  \
# 0     Watch the full episode here:- https://youtu.be...
# 1     Watch the full episode here:- https://youtu.be...
# 2     Watch the full episode here:- https://youtu.be...
# 3     Watch the full episode here:- https://youtu.be...
# 4     Watch the Full Episode here:- https://youtu.be...
# ...                                                 ...
# 2152  Are carbs good or bad?\nIn today's video, i'm ...
# 2153  7 hour slow roasted pulled pork with beer sauc...
# 2154  How to lose weight fast - For any INDIAN - TOP...
# 2155  Gym tips for beginners - INDIA!\nHey guys, in ...
# 2156  🎧 Listen To #TheRanveerShow On Spotify:\nhttps...
#
#                                                    tags  \
# 0     [podcast, indian podcast, indian podcasts engl...
# 1     [podcast, indian podcast, indian podcasts engl...
# 2     [podcast, indian podcast, indian podcasts engl...
# 3     [podcast, indian podcast, indian podcasts engl...
# 4     [podcast, indian podcast, indian podcasts engl...
# ...                                                 ...
# 2152  [Nutrition (Medical Specialty), Carbohydrate (...
# 2153  [Pulled Pork (Food), Roasting (Culinary Techni...
# 2154  [Diet (Industry), Weight Loss (Symptom), Dieti...
# 2155  [India (Country), Indian gymmer, Indian gymmin...
# 2156  [beerbiceps, beerbiceps first video, beerbicep...
#
#                    publishedAt  viewCount  likeCount  favouriteCount  \
# 0    2024-09-21 12:30:33+00:00    21323.0      927.0             NaN
# 1    2024-09-21 12:02:32+00:00    11567.0      494.0             NaN
# 2    2024-09-21 12:00:31+00:00    57383.0     2998.0             NaN
# 3    2024-09-20 15:30:17+00:00    91279.0     3542.0             NaN
# 4    2024-09-20 15:30:17+00:00    65681.0     3017.0             NaN
# ...                        ...        ...        ...             ...
# 2152 2015-08-19 16:28:46+00:00    79502.0     2775.0             NaN
# 2153 2015-08-16 17:20:52+00:00   109626.0     1395.0             NaN
# 2154 2015-08-15 16:57:31+00:00    64504.0     1534.0             NaN
# 2155 2015-08-15 14:53:45+00:00   116944.0     3473.0             NaN
# 2156 2015-08-15 13:52:59+00:00   358082.0    12382.0             NaN
#
#       commentCount  duration definition caption pushblishDayName  \
# 0              8.0     PT37S         hd   false         Saturday
# 1              4.0     PT46S         hd   false         Saturday
# 2             20.0     PT39S         hd   false         Saturday
# 3             50.0     PT33S         hd   false           Friday
# 4             25.0     PT43S         hd   false           Friday
# ...            ...       ...        ...     ...              ...
# 2152         133.0   PT3M11S         hd   false        Wednesday
# 2153         301.0  PT11M14S         hd   false           Sunday
# 2154          68.0    PT5M2S         hd   false         Saturday
# 2155         147.0    PT5M2S         hd   false         Saturday
# 2156         897.0    PT4M2S         hd   false         Saturday
#
#       durationSecs  tagCount
# 0             37.0        32
# 1             46.0        32
# 2             39.0        32
# 3             33.0        32
# 4             43.0        34
# ...            ...       ...
# 2152         191.0        26
# 2153         674.0        23
# 2154         302.0        28
# 2155         302.0        23
# 2156         242.0         5
#
# [2157 rows x 16 columns]

# %% [markdown]
# ## Data Analyis

# %% [markdown]
# ### Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Worst Performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### View distribution per video

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# /Users/sammd/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ### Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Video duration

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=40)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ### Wordcloud for video titles

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ### Upload schedule

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
